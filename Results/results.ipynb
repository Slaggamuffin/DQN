# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
dqnv3 = np.loadtxt('DQNv3.csv')
DoubleDQN = np.loadtxt('DoubleDQN_300ep.csv')

# %%
plt.plot(dqnv3)
plt.plot(DoubleDQN)

plt.show()
